# %% [markdown]
# <font size=5, font color='blue'> stata_df is the dataframe downloaded through Stata API

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

stata_df = pd.read_stata("BIS_USDfx.dta")
stata_df.head()
# Out:
#    period period_start_day   value obs_conf obs_status frequency dataset_code  \
# 0    1966       1966-01-01  4.7619        F          A    annual       WS_XRU
# 1    1967       1967-01-01  4.7619        F          A    annual       WS_XRU
# 2    1968       1968-01-01  4.7619        F          A    annual       WS_XRU
# 3    1969       1969-01-01  4.7619        F          A    annual       WS_XRU
# 4    1970       1970-01-01  4.7619        F          A    annual       WS_XRU
#
#                dataset_name collection currency freq ref_area  \
# 0  US dollar exchange rates          A      AED    A       AE
# 1  US dollar exchange rates          A      AED    A       AE
# 2  US dollar exchange rates          A      AED    A       AE
# 3  US dollar exchange rates          A      AED    A       AE
# 4  US dollar exchange rates          A      AED    A       AE
#
#                  indexed_at provider_code series_code  \
# 0  2025-06-13T15:24:25.093Z           BIS  A.AE.AED.A
# 1  2025-06-13T15:24:25.093Z           BIS  A.AE.AED.A
# 2  2025-06-13T15:24:25.093Z           BIS  A.AE.AED.A
# 3  2025-06-13T15:24:25.093Z           BIS  A.AE.AED.A
# 4  2025-06-13T15:24:25.093Z           BIS  A.AE.AED.A
#
#                                          series_name series_num
# 0   Exchange rates against USD United Arab Emirat...     Master
# 1   Exchange rates against USD United Arab Emirat...     Master
# 2   Exchange rates against USD United Arab Emirat...     Master
# 3   Exchange rates against USD United Arab Emirat...     Master
# 4   Exchange rates against USD United Arab Emirat...     Master

# %% [markdown]
# <font size=5, font color='blue'> python_df is the dataframe downloaded through Python API.

# %%
python_df = pd.read_pickle("BIS_USDfx.pkl")
python_df.head()
# Out:
#   @frequency provider_code dataset_code              dataset_name series_code  \
# 0     annual           BIS       WS_XRU  US dollar exchange rates  A.AE.AED.A
# 1     annual           BIS       WS_XRU  US dollar exchange rates  A.AE.AED.A
# 2     annual           BIS       WS_XRU  US dollar exchange rates  A.AE.AED.A
# 3     annual           BIS       WS_XRU  US dollar exchange rates  A.AE.AED.A
# 4     annual           BIS       WS_XRU  US dollar exchange rates  A.AE.AED.A
#
#                                          series_name original_period  \
# 0   Exchange rates against USD United Arab Emirat...            1966
# 1   Exchange rates against USD United Arab Emirat...            1967
# 2   Exchange rates against USD United Arab Emirat...            1968
# 3   Exchange rates against USD United Arab Emirat...            1969
# 4   Exchange rates against USD United Arab Emirat...            1970
#
#       period original_value   value FREQ REF_AREA CURRENCY COLLECTION  \
# 0 1966-01-01         4.7619  4.7619    A       AE      AED          A
# 1 1967-01-01         4.7619  4.7619    A       AE      AED          A
# 2 1968-01-01         4.7619  4.7619    A       AE      AED          A
# 3 1969-01-01         4.7619  4.7619    A       AE      AED          A
# 4 1970-01-01         4.7619  4.7619    A       AE      AED          A
#
#   Frequency        Reference area    Currency  \
# 0    Annual  United Arab Emirates  UAE dirham
# 1    Annual  United Arab Emirates  UAE dirham
# 2    Annual  United Arab Emirates  UAE dirham
# 3    Annual  United Arab Emirates  UAE dirham
# 4    Annual  United Arab Emirates  UAE dirham
#
#                                Collection
# 0  Average of observations through period
# 1  Average of observations through period
# 2  Average of observations through period
# 3  Average of observations through period
# 4  Average of observations through period

# %% [markdown]
# <font size=5, font color='blue'> Check whether the two dataframes have the same number of rows, which means equal number of data points / observations. Column numbers of the two dataframes may differ due to the difference between Stata and Python APIs, and so do the order, datatypes and names of columns and the order of rows, which is why we don't require a complete match between python_df and stata_df.

# %%
stata_df.shape[0]==python_df.shape[0]
# Out:
# True

# %% [markdown]
# <font size=5, font color='blue'> ['period_start_day'] in stata_df is the most accurate timestamp assigned to each observation (row). In python_df its equivalent is ['period'], so we rename it to match the column name in stata_df. We match the datatype of the two columns by converting both of them to pandas datetime objects. We also convert the datatype of ['value'] in stata_df to numeric.

# %%
python_df.rename(columns={'period':'period_start_day'},inplace=True)
stata_df['period_start_day'] = pd.to_datetime(stata_df['period_start_day'])
python_df['period_start_day'] = pd.to_datetime(python_df['period_start_day'])
stata_df['value'] = pd.to_numeric(stata_df['value'],'coerce')

# %% [markdown]
# <font size=5, font color='blue'> Check whether ['period_start_day', 'series_code'] can identify a unique row in both stata_df and python_df, if not then there is a duplication or error in Dbnomics.

# %%
cols = ['period_start_day', 'series_code']
sum(stata_df.duplicated(subset=cols))+sum(python_df.duplicated(subset=cols)) == 0
# Out:
# True

# %% [markdown]
# <font size=5, font color='blue'> Then we sort the two dataframes by ['period_start_day', 'series_code']. This ensures observations in the two dataframes are in the same order. Finally we check whether the two sub-frames [['period_start_day','series_code','value']] sliced from stata_df and python_df are exactly the same.

# %%
stata_sub = stata_df.sort_values(by=cols)[cols+['value']].reset_index(drop=True)
python_sub = python_df.sort_values(by=cols)[cols+['value']].reset_index(drop=True)
stata_sub.equals(python_sub)
# Out:
# True
