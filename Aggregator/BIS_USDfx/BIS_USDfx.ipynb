# %%
import pandas as pd

from dbnomics import fetch_series

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df = fetch_series("BIS", "WS_XRU", dimensions={"FREQ": ['A'], 'COLLECTION':['A']}, max_nb_series=1000000)
df = df.reset_index(drop=True)
df.head(20)
# Out:
#    @frequency provider_code dataset_code              dataset_name  \
# 0      annual           BIS       WS_XRU  US dollar exchange rates
# 1      annual           BIS       WS_XRU  US dollar exchange rates
# 2      annual           BIS       WS_XRU  US dollar exchange rates
# 3      annual           BIS       WS_XRU  US dollar exchange rates
# 4      annual           BIS       WS_XRU  US dollar exchange rates
# 5      annual           BIS       WS_XRU  US dollar exchange rates
# 6      annual           BIS       WS_XRU  US dollar exchange rates
# 7      annual           BIS       WS_XRU  US dollar exchange rates
# 8      annual           BIS       WS_XRU  US dollar exchange rates
# 9      annual           BIS       WS_XRU  US dollar exchange rates
# 10     annual           BIS       WS_XRU  US dollar exchange rates
# 11     annual           BIS       WS_XRU  US dollar exchange rates
# 12     annual           BIS       WS_XRU  US dollar exchange rates
# ...

# %%
df.to_excel('BIS_USDfx.xlsx')

# %%
df.to_pickle("BIS_USDfx.pkl")

# %%
df1 = pd.read_pickle("BIS_USDfx.pkl")
df1.equals(df)
# Out:
# True
