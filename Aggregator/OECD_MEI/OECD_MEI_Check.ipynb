# %% [markdown]
# <font size=5, font color='blue'> stata_df is the dataframe downloaded through Stata API

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

stata_df = pd.read_stata("OECD_MEI.dta")
stata_df.head()
# Out:
#    period period_start_day  value frequency dataset_code  \
# 0    1955       1955-01-01    5.0    annual          MEI
# 1    1956       1956-01-01    5.0    annual          MEI
# 2    1957       1957-01-01    5.0    annual          MEI
# 3    1958       1958-01-01    5.0    annual          MEI
# 4    1959       1959-01-01    4.5    annual          MEI
#
#                            dataset_name FREQUENCY location measure   subject  \
# 0  Main Economic Indicators Publication         A      AUT      ST  IRSTCB01
# 1  Main Economic Indicators Publication         A      AUT      ST  IRSTCB01
# 2  Main Economic Indicators Publication         A      AUT      ST  IRSTCB01
# 3  Main Economic Indicators Publication         A      AUT      ST  IRSTCB01
# 4  Main Economic Indicators Publication         A      AUT      ST  IRSTCB01
#
#                  indexed_at provider_code        series_code  \
# 0  2024-07-02T13:48:18.483Z          OECD  AUT.IRSTCB01.ST.A
# 1  2024-07-02T13:48:18.483Z          OECD  AUT.IRSTCB01.ST.A
# 2  2024-07-02T13:48:18.483Z          OECD  AUT.IRSTCB01.ST.A
# 3  2024-07-02T13:48:18.483Z          OECD  AUT.IRSTCB01.ST.A
# 4  2024-07-02T13:48:18.483Z          OECD  AUT.IRSTCB01.ST.A
#
#                                          series_name series_num
# 0  Austria – Interest Rates > Immediate rates (< ...     Master
# 1  Austria – Interest Rates > Immediate rates (< ...     Master
# 2  Austria – Interest Rates > Immediate rates (< ...     Master
# 3  Austria – Interest Rates > Immediate rates (< ...     Master
# 4  Austria – Interest Rates > Immediate rates (< ...     Master

# %% [markdown]
# <font size=5, font color='blue'> python_df is the dataframe downloaded through Python API.

# %%
python_df = pd.read_pickle("OECD_MEI.pkl")
python_df.head()
# Out:
#   @frequency provider_code dataset_code                          dataset_name  \
# 0     annual          OECD          MEI  Main Economic Indicators Publication
# 1     annual          OECD          MEI  Main Economic Indicators Publication
# 2     annual          OECD          MEI  Main Economic Indicators Publication
# 3     annual          OECD          MEI  Main Economic Indicators Publication
# 4     annual          OECD          MEI  Main Economic Indicators Publication
#
#            series_code                                        series_name  \
# 0  AUS.MABMM301.STSA.A  Australia – Monetary aggregates and their comp...
# 1  AUS.MABMM301.STSA.A  Australia – Monetary aggregates and their comp...
# 2  AUS.MABMM301.STSA.A  Australia – Monetary aggregates and their comp...
# 3  AUS.MABMM301.STSA.A  Australia – Monetary aggregates and their comp...
# 4  AUS.MABMM301.STSA.A  Australia – Monetary aggregates and their comp...
#
#   original_period     period original_value     value LOCATION   SUBJECT  \
# 0            1960 1960-01-01         7.2325  7.232500      AUS  MABMM301
# 1            1961 1961-01-01        7.42625  7.426250      AUS  MABMM301
# 2            1962 1962-01-01        7.98175  7.981750      AUS  MABMM301
# 3            1963 1963-01-01         8.6835  8.683500      AUS  MABMM301
# 4            1964 1964-01-01       9.711667  9.711667      AUS  MABMM301
#
#   MEASURE FREQUENCY    Country  \
# 0    STSA         A  Australia
# 1    STSA         A  Australia
# 2    STSA         A  Australia
# 3    STSA         A  Australia
# 4    STSA         A  Australia
#
#                                              Subject  \
# 0  Monetary aggregates and their components > Bro...
# 1  Monetary aggregates and their components > Bro...
# 2  Monetary aggregates and their components > Bro...
# 3  Monetary aggregates and their components > Bro...
# 4  Monetary aggregates and their components > Bro...
#
#                                   Measure Frequency
# 0  Level, rate or national currency, s.a.    Annual
# 1  Level, rate or national currency, s.a.    Annual
# 2  Level, rate or national currency, s.a.    Annual
# 3  Level, rate or national currency, s.a.    Annual
# 4  Level, rate or national currency, s.a.    Annual

# %% [markdown]
# <font size=5, font color='blue'> Check whether the two dataframes have the same number of rows, which means equal number of data points / observations. Column numbers of the two dataframes may differ due to the difference between Stata and Python APIs, and so do the order, datatypes and names of columns and the order of rows, which is why we don't require a complete match between python_df and stata_df.

# %%
stata_df.shape[0]==python_df.shape[0]
# Out:
# True

# %% [markdown]
# <font size=5, font color='blue'> ['period_start_day'] in stata_df is the most accurate timestamp assigned to each observation (row). In python_df its equivalent is ['period'], so we rename it to match the column name in stata_df. We match the datatype of the two columns by converting both of them to pandas datetime objects. We also convert the datatype of ['value'] in stata_df to numeric.

# %%
python_df.rename(columns={'period':'period_start_day'},inplace=True)
stata_df['period_start_day'] = pd.to_datetime(stata_df['period_start_day'])
python_df['period_start_day'] = pd.to_datetime(python_df['period_start_day'])
stata_df['value'] = pd.to_numeric(stata_df['value'],'coerce')

# %% [markdown]
# <font size=5, font color='blue'> Check whether ['period_start_day', 'series_code'] can identify a unique row in both stata_df and python_df, if not then there is a duplication or error in Dbnomics.

# %%
cols = ['period_start_day', 'series_code']
sum(stata_df.duplicated(subset=cols))+sum(python_df.duplicated(subset=cols)) == 0
# Out:
# True

# %% [markdown]
# <font size=5, font color='blue'> Then we sort the two dataframes by ['period_start_day', 'series_code']. This ensures observations in the two dataframes are in the same order. Finally we check whether the two sub-frames [['period_start_day','series_code','value']] sliced from stata_df and python_df are exactly the same.

# %%
stata_sub = stata_df.sort_values(by=cols)[cols+['value']].reset_index(drop=True)
python_sub = python_df.sort_values(by=cols)[cols+['value']].reset_index(drop=True)
stata_sub.equals(python_sub)
# Out:
# True
