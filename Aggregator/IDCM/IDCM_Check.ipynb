# %% [markdown]
# <font size=5, font color='blue'> stata_df is the dataframe downloaded through Stata API

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

stata_df = pd.read_stata("IDCM.dta")
stata_df.head()
# Out:
#    period period_start_day      value frequency dataset_code  \
# 0    2000       2000-01-01  1113.7784    annual         IDCM
# 1    2001       2001-01-01  1164.5364    annual         IDCM
# 2    2002       2002-01-01  1272.0211    annual         IDCM
# 3    2003       2003-01-01  1339.8700    annual         IDCM
# 4    2004       2004-01-01  1414.8110    annual         IDCM
#
#                                         dataset_name accounting_entry  \
# 0  National accounts, Main aggregates in the Inte...                C
# 1  National accounts, Main aggregates in the Inte...                C
# 2  National accounts, Main aggregates in the Inte...                C
# 3  National accounts, Main aggregates in the Inte...                C
# 4  National accounts, Main aggregates in the Inte...                C
#
#   activity adjustment counterpart_area  ... ref_area ref_sector sto  \
# 0       _Z          N               W1  ...       AD         S1  P7
# 1       _Z          N               W1  ...       AD         S1  P7
# 2       _Z          N               W1  ...       AD         S1  P7
# 3       _Z          N               W1  ...       AD         S1  P7
# 4       _Z          N               W1  ...       AD         S1  P7
#
#   transformation unit_measure                indexed_at provider_code  \
# 0              N          XDC  2025-02-03T10:42:49.455Z           ECB
# 1              N          XDC  2025-02-03T10:42:49.455Z           ECB
# 2              N          XDC  2025-02-03T10:42:49.455Z           ECB
# 3              N          XDC  2025-02-03T10:42:49.455Z           ECB
# 4              N          XDC  2025-02-03T10:42:49.455Z           ECB
#
#                              series_code  \
# 0  A.N.AD.W1.S1.S1.C.P7._Z._Z._Z.XDC.V.N
# 1  A.N.AD.W1.S1.S1.C.P7._Z._Z._Z.XDC.V.N
# 2  A.N.AD.W1.S1.S1.C.P7._Z._Z._Z.XDC.V.N
# 3  A.N.AD.W1.S1.S1.C.P7._Z._Z._Z.XDC.V.N
# 4  A.N.AD.W1.S1.S1.C.P7._Z._Z._Z.XDC.V.N
#
#                                          series_name series_num
# 0  Annual – Neither seasonally adjusted nor calen...     Master
# 1  Annual – Neither seasonally adjusted nor calen...     Master
# 2  Annual – Neither seasonally adjusted nor calen...     Master
# 3  Annual – Neither seasonally adjusted nor calen...     Master
# 4  Annual – Neither seasonally adjusted nor calen...     Master
#
# [5 rows x 25 columns]

# %% [markdown]
# <font size=5, font color='blue'> python_df is the dataframe downloaded through Python API.

# %%
python_df = pd.read_pickle("IDCM.pkl")
python_df.head()
# Out:
#   @frequency provider_code dataset_code  \
# 0     annual           ECB         IDCM
# 1     annual           ECB         IDCM
# 2     annual           ECB         IDCM
# 3     annual           ECB         IDCM
# 4     annual           ECB         IDCM
#
#                                         dataset_name  \
# 0  National accounts, Main aggregates in the Inte...
# 1  National accounts, Main aggregates in the Inte...
# 2  National accounts, Main aggregates in the Inte...
# 3  National accounts, Main aggregates in the Inte...
# 4  National accounts, Main aggregates in the Inte...
#
#                                series_code  \
# 0  A.N.AD.W2.S1.S1.B.B1GQ._Z._Z._Z.XDC.Q.N
# 1  A.N.AD.W2.S1.S1.B.B1GQ._Z._Z._Z.XDC.Q.N
# 2  A.N.AD.W2.S1.S1.B.B1GQ._Z._Z._Z.XDC.Q.N
# 3  A.N.AD.W2.S1.S1.B.B1GQ._Z._Z._Z.XDC.Q.N
# 4  A.N.AD.W2.S1.S1.B.B1GQ._Z._Z._Z.XDC.Q.N
#
#                                          series_name original_period  \
# 0  Annual – Neither seasonally adjusted nor calen...            2000
# 1  Annual – Neither seasonally adjusted nor calen...            2001
# 2  Annual – Neither seasonally adjusted nor calen...            2002
# 3  Annual – Neither seasonally adjusted nor calen...            2003
# 4  Annual – Neither seasonally adjusted nor calen...            2004
#
#       period  original_value      value  ... Reference sector  \
# 0 2000-01-01       1991.6637  1991.6637  ...    Total economy
# 1 2001-01-01       2153.3720  2153.3720  ...    Total economy
# 2 2002-01-01       2251.2742  2251.2742  ...    Total economy
# 3 2003-01-01       2447.0017  2447.0017  ...    Total economy
# 4 2004-01-01       2646.0804  2646.0804  ...    Total economy
#
#   Counterpart sector              Accounting entries  \
# 0      Total economy  Balance (Credits minus Debits)
# 1      Total economy  Balance (Credits minus Debits)
# 2      Total economy  Balance (Credits minus Debits)
# 3      Total economy  Balance (Credits minus Debits)
# 4      Total economy  Balance (Credits minus Debits)
#
#          Stocks, Transactions, Other Flows  \
# 0  Gross domestic product at market prices
# 1  Gross domestic product at market prices
# 2  Gross domestic product at market prices
# 3  Gross domestic product at market prices
# 4  Gross domestic product at market prices
#
#   Instrument and assets classification Activity classification  \
# 0                       Not applicable          Not applicable
# 1                       Not applicable          Not applicable
# 2                       Not applicable          Not applicable
# 3                       Not applicable          Not applicable
# 4                       Not applicable          Not applicable
#
#   Expenditure (COFOG, COICOP, COPP or COPNI)  \
# 0                             Not applicable
# 1                             Not applicable
# 2                             Not applicable
# 3                             Not applicable
# 4                             Not applicable
#
#                                      Unit of measure           Prices  \
# 0  Domestic currency (incl. conversion to current...  Constant prices
# 1  Domestic currency (incl. conversion to current...  Constant prices
# 2  Domestic currency (incl. conversion to current...  Constant prices
# 3  Domestic currency (incl. conversion to current...  Constant prices
# 4  Domestic currency (incl. conversion to current...  Constant prices
#
#          Transformation
# 0  Non transformed data
# 1  Non transformed data
# 2  Non transformed data
# 3  Non transformed data
# 4  Non transformed data
#
# [5 rows x 38 columns]

# %% [markdown]
# <font size=5, font color='blue'> Check whether the two dataframes have the same number of rows, which means equal number of data points / observations. Column numbers of the two dataframes may differ due to the difference between Stata and Python APIs, and so do the order, datatypes and names of columns and the order of rows, which is why we don't require a complete match between python_df and stata_df.

# %%
stata_df.shape[0]==python_df.shape[0]
# Out:
# True

# %% [markdown]
# <font size=5, font color='blue'> ['period_start_day'] in stata_df is the most accurate timestamp assigned to each observation (row). In python_df its equivalent is ['period'], so we rename it to match the column name in stata_df. We match the datatype of the two columns by converting both of them to pandas datetime objects. We also convert the datatype of ['value'] in stata_df to numeric.

# %%
python_df.rename(columns={'period':'period_start_day'},inplace=True)
stata_df['period_start_day'] = pd.to_datetime(stata_df['period_start_day'])
python_df['period_start_day'] = pd.to_datetime(python_df['period_start_day'])
stata_df['value'] = pd.to_numeric(stata_df['value'],'coerce')

# %% [markdown]
# <font size=5, font color='blue'> Check whether ['period_start_day', 'series_code'] can identify a unique row in both stata_df and python_df, if not then there is a duplication or error in Dbnomics.

# %%
cols = ['period_start_day', 'series_code']
sum(stata_df.duplicated(subset=cols))+sum(python_df.duplicated(subset=cols)) == 0
# Out:
# True

# %% [markdown]
# <font size=5, font color='blue'> Then we sort the two dataframes by ['period_start_day', 'series_code']. This ensures observations in the two dataframes are in the same order. Finally we check whether the two sub-frames [['period_start_day','series_code','value']] sliced from stata_df and python_df are exactly the same.

# %%
stata_sub = stata_df.sort_values(by=cols)[cols+['value']].reset_index(drop=True)
python_sub = python_df.sort_values(by=cols)[cols+['value']].reset_index(drop=True)
stata_sub.equals(python_sub)
# Out:
# True
