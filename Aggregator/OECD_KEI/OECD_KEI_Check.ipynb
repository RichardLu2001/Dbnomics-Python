# %% [markdown]
# <font size=5, font color='blue'> stata_df is the dataframe downloaded through Stata API

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

stata_df = pd.read_stata("OECD_KEI.dta")
stata_df.head()
# Out:
#    period period_start_day  value frequency dataset_code  \
# 0    1967       1967-01-01  1.875    annual          KEI
# 1    1968       1968-01-01  1.850    annual          KEI
# 2    1969       1969-01-01  1.800    annual          KEI
# 3    1970       1970-01-01  1.625    annual          KEI
# 4    1971       1971-01-01  1.925    annual          KEI
#
#                          dataset_name FREQUENCY location measure   subject  \
# 0  Key Short-Term Economic Indicators         A      AUS      ST  LRHUTTTT
# 1  Key Short-Term Economic Indicators         A      AUS      ST  LRHUTTTT
# 2  Key Short-Term Economic Indicators         A      AUS      ST  LRHUTTTT
# 3  Key Short-Term Economic Indicators         A      AUS      ST  LRHUTTTT
# 4  Key Short-Term Economic Indicators         A      AUS      ST  LRHUTTTT
#
#                  indexed_at provider_code        series_code  \
# 0  2024-10-31T09:51:20.215Z          OECD  LRHUTTTT.AUS.ST.A
# 1  2024-10-31T09:51:20.215Z          OECD  LRHUTTTT.AUS.ST.A
# 2  2024-10-31T09:51:20.215Z          OECD  LRHUTTTT.AUS.ST.A
# 3  2024-10-31T09:51:20.215Z          OECD  LRHUTTTT.AUS.ST.A
# 4  2024-10-31T09:51:20.215Z          OECD  LRHUTTTT.AUS.ST.A
#
#                                          series_name series_num
# 0  Monthly unemployment rate: all persons, s.a. –...     Master
# 1  Monthly unemployment rate: all persons, s.a. –...     Master
# 2  Monthly unemployment rate: all persons, s.a. –...     Master
# 3  Monthly unemployment rate: all persons, s.a. –...     Master
# 4  Monthly unemployment rate: all persons, s.a. –...     Master

# %% [markdown]
# <font size=5, font color='blue'> python_df is the dataframe downloaded through Python API.

# %%
python_df = pd.read_pickle("OECD_KEI.pkl")
python_df.head()
# Out:
#   @frequency provider_code dataset_code                        dataset_name  \
# 0     annual          OECD          KEI  Key Short-Term Economic Indicators
# 1     annual          OECD          KEI  Key Short-Term Economic Indicators
# 2     annual          OECD          KEI  Key Short-Term Economic Indicators
# 3     annual          OECD          KEI  Key Short-Term Economic Indicators
# 4     annual          OECD          KEI  Key Short-Term Economic Indicators
#
#          series_code                                        series_name  \
# 0  B6BLTT02.ARG.ST.A  Current account as a % of GDP, s.a. – Argentin...
# 1  B6BLTT02.ARG.ST.A  Current account as a % of GDP, s.a. – Argentin...
# 2  B6BLTT02.ARG.ST.A  Current account as a % of GDP, s.a. – Argentin...
# 3  B6BLTT02.ARG.ST.A  Current account as a % of GDP, s.a. – Argentin...
# 4  B6BLTT02.ARG.ST.A  Current account as a % of GDP, s.a. – Argentin...
#
#   original_period     period original_value     value   SUBJECT LOCATION  \
# 0            2006 2006-01-01       2.835994  2.835994  B6BLTT02      ARG
# 1            2007 2007-01-01       2.135934  2.135934  B6BLTT02      ARG
# 2            2008 2008-01-01       1.491886  1.491886  B6BLTT02      ARG
# 3            2009 2009-01-01       2.178952  2.178952  B6BLTT02      ARG
# 4            2010 2010-01-01       -0.42923 -0.429230  B6BLTT02      ARG
#
#   MEASURE FREQUENCY                              Subject    Country  \
# 0      ST         A  Current account as a % of GDP, s.a.  Argentina
# 1      ST         A  Current account as a % of GDP, s.a.  Argentina
# 2      ST         A  Current account as a % of GDP, s.a.  Argentina
# 3      ST         A  Current account as a % of GDP, s.a.  Argentina
# 4      ST         A  Current account as a % of GDP, s.a.  Argentina
#
#                  Measure Frequency
# 0  Level, ratio or index    Annual
# 1  Level, ratio or index    Annual
# 2  Level, ratio or index    Annual
# 3  Level, ratio or index    Annual
# 4  Level, ratio or index    Annual

# %% [markdown]
# <font size=5, font color='blue'> Check whether the two dataframes have the same number of rows, which means equal number of data points / observations. Column numbers of the two dataframes may differ due to the difference between Stata and Python APIs, and so do the order, datatypes and names of columns and the order of rows, which is why we don't require a complete match between python_df and stata_df.

# %%
stata_df.shape[0]==python_df.shape[0]
# Out:
# True

# %% [markdown]
# <font size=5, font color='blue'> ['period_start_day'] in stata_df is the most accurate timestamp assigned to each observation (row). In python_df its equivalent is ['period'], so we rename it to match the column name in stata_df. We match the datatype of the two columns by converting both of them to pandas datetime objects. We also convert the datatype of ['value'] in stata_df to numeric.

# %%
python_df.rename(columns={'period':'period_start_day'},inplace=True)
stata_df['period_start_day'] = pd.to_datetime(stata_df['period_start_day'])
python_df['period_start_day'] = pd.to_datetime(python_df['period_start_day'])
stata_df['value'] = pd.to_numeric(stata_df['value'],'coerce')

# %% [markdown]
# <font size=5, font color='blue'> Check whether ['period_start_day', 'series_code'] can identify a unique row in both stata_df and python_df, if not then there is a duplication or error in Dbnomics.

# %%
cols = ['period_start_day', 'series_code']
sum(stata_df.duplicated(subset=cols))+sum(python_df.duplicated(subset=cols)) == 0
# Out:
# True

# %% [markdown]
# <font size=5, font color='blue'> Then we sort the two dataframes by ['period_start_day', 'series_code']. This ensures observations in the two dataframes are in the same order. Finally we check whether the two sub-frames [['period_start_day','series_code','value']] sliced from stata_df and python_df are exactly the same.

# %%
stata_sub = stata_df.sort_values(by=cols)[cols+['value']].reset_index(drop=True)
python_sub = python_df.sort_values(by=cols)[cols+['value']].reset_index(drop=True)
stata_sub.equals(python_sub)
# Out:
# True
