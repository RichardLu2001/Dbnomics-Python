# %%
import pandas as pd

from dbnomics import fetch_series

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df = fetch_series("BIS", "WS_CBPOL", dimensions={"FREQ": ['M']}, max_nb_series=1000000)
df = df.reset_index(drop=True)
df.head(20)
# Out:
#    @frequency provider_code dataset_code               dataset_name  \
# 0     monthly           BIS     WS_CBPOL  Central bank policy rates
# 1     monthly           BIS     WS_CBPOL  Central bank policy rates
# 2     monthly           BIS     WS_CBPOL  Central bank policy rates
# 3     monthly           BIS     WS_CBPOL  Central bank policy rates
# 4     monthly           BIS     WS_CBPOL  Central bank policy rates
# 5     monthly           BIS     WS_CBPOL  Central bank policy rates
# 6     monthly           BIS     WS_CBPOL  Central bank policy rates
# 7     monthly           BIS     WS_CBPOL  Central bank policy rates
# 8     monthly           BIS     WS_CBPOL  Central bank policy rates
# 9     monthly           BIS     WS_CBPOL  Central bank policy rates
# 10    monthly           BIS     WS_CBPOL  Central bank policy rates
# 11    monthly           BIS     WS_CBPOL  Central bank policy rates
# 12    monthly           BIS     WS_CBPOL  Central bank policy rates
# ...

# %%
df.to_excel('BIS_cbrate.xlsx')

# %%
df.to_pickle("BIS_cbrate.pkl")

# %%
df1 = pd.read_pickle("BIS_cbrate.pkl")
df1.equals(df)
# Out:
# True
