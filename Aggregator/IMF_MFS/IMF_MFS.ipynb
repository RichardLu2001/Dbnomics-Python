# %%
import pandas as pd

from dbnomics import fetch_series

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
indicators = ['14____XDC','FMA_XDC','34____XDC','FMBCC_XDC','35L___XDC','FMB_XDC','FITB_PA','FPOLM_PA','FIGB_PA']

# %%
df = fetch_series("IMF", "MFS", dimensions={"INDICATOR": indicators}, max_nb_series=1000000)
df = df.reset_index(drop=True)
df.head(20)
# Out:
#    @frequency provider_code dataset_code  \
# 0      annual           IMF          MFS
# 1      annual           IMF          MFS
# 2      annual           IMF          MFS
# 3      annual           IMF          MFS
# 4      annual           IMF          MFS
# 5      annual           IMF          MFS
# 6      annual           IMF          MFS
# 7      annual           IMF          MFS
# 8      annual           IMF          MFS
# 9      annual           IMF          MFS
# 10     annual           IMF          MFS
# 11     annual           IMF          MFS
# 12     annual           IMF          MFS
# 13     annual           IMF          MFS
# 14     annual           IMF          MFS
# 15     annual           IMF          MFS
# 16     annual           IMF          MFS
# 17     annual           IMF          MFS
# 18     annual           IMF          MFS
# 19     annual           IMF          MFS
#
#                                dataset_name     series_code  \
# ...

# %%
df.to_excel('IMF_MFS.xlsx')

# %%
df.to_pickle("IMF_MFS.pkl")

# %%
df1 = pd.read_pickle("IMF_MFS.pkl")
df1.equals(df)
# Out:
# True
