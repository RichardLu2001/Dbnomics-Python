# %%
import pandas as pd

gdp_url = "https://data.un.org/_Docs/SYB/CSV/SYB66_230_202310_GDP%20and%20GDP%20Per%20Capita.csv"
gdp_df = pd.read_csv(gdp_url, header=1, encoding="ISO-8859-1")  # use second row as header (0-indexed)

pop_url = "https://data.un.org/_Docs/SYB/CSV/SYB66_1_202310_Population,%20Surface%20Area%20and%20Density.csv"
pop_df = pd.read_csv(pop_url, header=1, encoding="ISO-8859-1")


combined_df = pd.concat([gdp_df, pop_df], ignore_index=True)

if "v2" in combined_df.columns:
    combined_df = combined_df.rename(columns={"v2": "country"})

# %%
combined_df.head(20)
# Out:
#     Region/Country/Area                     Unnamed: 1  Year  \
# 0                     1  Total, all countries or areas  1995
# 1                     1  Total, all countries or areas  2005
# 2                     1  Total, all countries or areas  2010
# 3                     1  Total, all countries or areas  2015
# 4                     1  Total, all countries or areas  2019
# 5                     1  Total, all countries or areas  2020
# 6                     1  Total, all countries or areas  2021
# 7                     1  Total, all countries or areas  1995
# 8                     1  Total, all countries or areas  2005
# 9                     1  Total, all countries or areas  2010
# 10                    1  Total, all countries or areas  2015
# 11                    1  Total, all countries or areas  2019
# 12                    1  Total, all countries or areas  2020
# 13                    1  Total, all countries or areas  2021
# ...

# %%
combined_df.to_excel('UN.xlsx')

# %%
combined_df.to_pickle("UN.pkl")

# %%
df1 = pd.read_pickle("UN.pkl")
df1.equals(combined_df)
# Out:
# True
