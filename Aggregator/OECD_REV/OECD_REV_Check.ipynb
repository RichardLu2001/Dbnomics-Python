# %% [markdown]
# <font size=5, font color='blue'> stata_df is the dataframe downloaded through Stata API

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

stata_df = pd.read_stata("OECD_REV.dta")
stata_df.head()
# Out:
#    period period_start_day   value frequency dataset_code  \
# 0    1973       1973-01-01  10.900    annual          REV
# 1    1974       1974-01-01  14.161    annual          REV
# 2    1975       1975-01-01  16.920    annual          REV
# 3    1976       1976-01-01  19.714    annual          REV
# 4    1977       1977-01-01  21.429    annual          REV
#
#                                         dataset_name  cou  gov       tax  \
# 0  Revenue Statistics - OECD countries: Comparati...  AUS  FED  TOTALTAX
# 1  Revenue Statistics - OECD countries: Comparati...  AUS  FED  TOTALTAX
# 2  Revenue Statistics - OECD countries: Comparati...  AUS  FED  TOTALTAX
# 3  Revenue Statistics - OECD countries: Comparati...  AUS  FED  TOTALTAX
# 4  Revenue Statistics - OECD countries: Comparati...  AUS  FED  TOTALTAX
#
#       var                indexed_at provider_code              series_code  \
# 0  TAXNAT  2024-04-06T11:38:14.560Z          OECD  FED.TOTALTAX.TAXNAT.AUS
# 1  TAXNAT  2024-04-06T11:38:14.560Z          OECD  FED.TOTALTAX.TAXNAT.AUS
# 2  TAXNAT  2024-04-06T11:38:14.560Z          OECD  FED.TOTALTAX.TAXNAT.AUS
# 3  TAXNAT  2024-04-06T11:38:14.560Z          OECD  FED.TOTALTAX.TAXNAT.AUS
# 4  TAXNAT  2024-04-06T11:38:14.560Z          OECD  FED.TOTALTAX.TAXNAT.AUS
#
#                                          series_name series_num
# 0  Federal or Central government – Total tax reve...     Master
# 1  Federal or Central government – Total tax reve...     Master
# 2  Federal or Central government – Total tax reve...     Master
# 3  Federal or Central government – Total tax reve...     Master
# 4  Federal or Central government – Total tax reve...     Master

# %% [markdown]
# <font size=5, font color='blue'> python_df is the dataframe downloaded through Python API.

# %%
python_df = pd.read_pickle("OECD_REV.pkl")
python_df.head()
# Out:
#   @frequency provider_code dataset_code  \
# 0     annual          OECD          REV
# 1     annual          OECD          REV
# 2     annual          OECD          REV
# 3     annual          OECD          REV
# 4     annual          OECD          REV
#
#                                         dataset_name              series_code  \
# 0  Revenue Statistics - OECD countries: Comparati...  FED.TOTALTAX.TAXNAT.AUS
# 1  Revenue Statistics - OECD countries: Comparati...  FED.TOTALTAX.TAXNAT.AUS
# 2  Revenue Statistics - OECD countries: Comparati...  FED.TOTALTAX.TAXNAT.AUS
# 3  Revenue Statistics - OECD countries: Comparati...  FED.TOTALTAX.TAXNAT.AUS
# 4  Revenue Statistics - OECD countries: Comparati...  FED.TOTALTAX.TAXNAT.AUS
#
#                                          series_name original_period  \
# 0  Federal or Central government – Total tax reve...            1973
# 1  Federal or Central government – Total tax reve...            1974
# 2  Federal or Central government – Total tax reve...            1975
# 3  Federal or Central government – Total tax reve...            1976
# 4  Federal or Central government – Total tax reve...            1977
#
#       period original_value   value  GOV       TAX     VAR  COU  \
# 0 1973-01-01           10.9  10.900  FED  TOTALTAX  TAXNAT  AUS
# 1 1974-01-01         14.161  14.161  FED  TOTALTAX  TAXNAT  AUS
# 2 1975-01-01          16.92  16.920  FED  TOTALTAX  TAXNAT  AUS
# 3 1976-01-01         19.714  19.714  FED  TOTALTAX  TAXNAT  AUS
# 4 1977-01-01         21.429  21.429  FED  TOTALTAX  TAXNAT  AUS
#
#              Level of government        Tax revenue  \
# 0  Federal or Central government  Total tax revenue
# 1  Federal or Central government  Total tax revenue
# 2  Federal or Central government  Total tax revenue
# 3  Federal or Central government  Total tax revenue
# 4  Federal or Central government  Total tax revenue
#
#                           Indicator    Country
# 0  Tax revenue in national currency  Australia
# 1  Tax revenue in national currency  Australia
# 2  Tax revenue in national currency  Australia
# 3  Tax revenue in national currency  Australia
# 4  Tax revenue in national currency  Australia

# %% [markdown]
# <font size=5, font color='blue'> Check whether the two dataframes have the same number of rows, which means equal number of data points / observations. Column numbers of the two dataframes may differ due to the difference between Stata and Python APIs, and so do the order, datatypes and names of columns and the order of rows, which is why we don't require a complete match between python_df and stata_df.

# %%
stata_df.shape[0]==python_df.shape[0]
# Out:
# True

# %% [markdown]
# <font size=5, font color='blue'> ['period_start_day'] in stata_df is the most accurate timestamp assigned to each observation (row). In python_df its equivalent is ['period'], so we rename it to match the column name in stata_df. We match the datatype of the two columns by converting both of them to pandas datetime objects. We also convert the datatype of ['value'] in stata_df to numeric.

# %%
python_df.rename(columns={'period':'period_start_day'},inplace=True)
stata_df['period_start_day'] = pd.to_datetime(stata_df['period_start_day'])
python_df['period_start_day'] = pd.to_datetime(python_df['period_start_day'])
stata_df['value'] = pd.to_numeric(stata_df['value'],'coerce')

# %% [markdown]
# <font size=5, font color='blue'> Check whether ['period_start_day', 'series_code'] can identify a unique row in both stata_df and python_df, if not then there is a duplication or error in Dbnomics.

# %%
cols = ['period_start_day', 'series_code']
sum(stata_df.duplicated(subset=cols))+sum(python_df.duplicated(subset=cols)) == 0
# Out:
# True

# %% [markdown]
# <font size=5, font color='blue'> Then we sort the two dataframes by ['period_start_day', 'series_code']. This ensures observations in the two dataframes are in the same order. Finally we check whether the two sub-frames [['period_start_day','series_code','value']] sliced from stata_df and python_df are exactly the same.

# %%
stata_sub = stata_df.sort_values(by=cols)[cols+['value']].reset_index(drop=True)
python_sub = python_df.sort_values(by=cols)[cols+['value']].reset_index(drop=True)
stata_sub.equals(python_sub)
# Out:
# True
