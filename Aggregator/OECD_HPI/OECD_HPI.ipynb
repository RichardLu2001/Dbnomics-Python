# %%
import pandas as pd

from dbnomics import fetch_series

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df = fetch_series("OECD", "HOUSE_PRICES", dimensions={"FREQUENCY": ["A"]}, max_nb_series=1000000)
df.head(20)
# Out:
#    @frequency provider_code  dataset_code                        dataset_name  \
# 0      annual          OECD  HOUSE_PRICES  Analytical house prices indicators
# 1      annual          OECD  HOUSE_PRICES  Analytical house prices indicators
# 2      annual          OECD  HOUSE_PRICES  Analytical house prices indicators
# 3      annual          OECD  HOUSE_PRICES  Analytical house prices indicators
# 4      annual          OECD  HOUSE_PRICES  Analytical house prices indicators
# 5      annual          OECD  HOUSE_PRICES  Analytical house prices indicators
# 6      annual          OECD  HOUSE_PRICES  Analytical house prices indicators
# 7      annual          OECD  HOUSE_PRICES  Analytical house prices indicators
# 8      annual          OECD  HOUSE_PRICES  Analytical house prices indicators
# 9      annual          OECD  HOUSE_PRICES  Analytical house prices indicators
# 10     annual          OECD  HOUSE_PRICES  Analytical house prices indicators
# ...

# %%
df.to_excel('OECD_HPI.xlsx')

# %%
df.to_pickle("OECD_HPI.pkl")

# %%
df1 = pd.read_pickle("OECD_HPI.pkl")
df1.equals(df)
# Out:
# True
