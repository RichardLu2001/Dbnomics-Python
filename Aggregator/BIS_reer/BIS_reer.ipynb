# %%
import pandas as pd

from dbnomics import fetch_series

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df = fetch_series("BIS", "WS_EER", dimensions={'FREQ':['M'], 'EER_TYPE':['R'], 'EER_BASKET':['B']}, max_nb_series=1000000)
df = df.reset_index(drop=True)
df.head(20)
# Out:
#    @frequency provider_code dataset_code                  dataset_name  \
# 0     monthly           BIS       WS_EER  BIS effective exchange rates
# 1     monthly           BIS       WS_EER  BIS effective exchange rates
# 2     monthly           BIS       WS_EER  BIS effective exchange rates
# 3     monthly           BIS       WS_EER  BIS effective exchange rates
# 4     monthly           BIS       WS_EER  BIS effective exchange rates
# 5     monthly           BIS       WS_EER  BIS effective exchange rates
# 6     monthly           BIS       WS_EER  BIS effective exchange rates
# 7     monthly           BIS       WS_EER  BIS effective exchange rates
# 8     monthly           BIS       WS_EER  BIS effective exchange rates
# 9     monthly           BIS       WS_EER  BIS effective exchange rates
# 10    monthly           BIS       WS_EER  BIS effective exchange rates
# 11    monthly           BIS       WS_EER  BIS effective exchange rates
# ...

# %%
df.to_excel('BIS_reer.xlsx')

# %%
df.to_pickle("BIS_reer.pkl")

# %%
df1 = pd.read_pickle("BIS_reer.pkl")
df1.equals(df)
# Out:
# True
