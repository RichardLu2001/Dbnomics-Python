# %% [markdown]
# <font size=5, font color='blue'> stata_df is the dataframe downloaded through Stata API

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

stata_df = pd.read_stata("ITA_3.dta")
stata_df.head()
# Out:
#    period period_start_day value obs_status frequency           dataset_code  \
# 0    1995       1995-01-01    NA          t    annual  92_506_DF_DCCN_PILN_1
# 1    1996       1996-01-01    NA          t    annual  92_506_DF_DCCN_PILN_1
# 2    1997       1997-01-01    NA          t    annual  92_506_DF_DCCN_PILN_1
# 3    1998       1998-01-01    NA          t    annual  92_506_DF_DCCN_PILN_1
# 4    1999       1999-01-01    NA          t    annual  92_506_DF_DCCN_PILN_1
#
#                                  dataset_name adjustment data_type_aggr  \
# 0  Gross Domestic Product and main components          N         B1GQ_1
# 1  Gross Domestic Product and main components          N         B1GQ_1
# 2  Gross Domestic Product and main components          N         B1GQ_1
# 3  Gross Domestic Product and main components          N         B1GQ_1
# 4  Gross Domestic Product and main components          N         B1GQ_1
#
#   edition freq ref_area valuation                indexed_at provider_code  \
# 0  2024M9    A       IT    L_2020  2025-03-04T04:49:48.949Z         ISTAT
# 1  2024M9    A       IT    L_2020  2025-03-04T04:49:48.949Z         ISTAT
# 2  2024M9    A       IT    L_2020  2025-03-04T04:49:48.949Z         ISTAT
# 3  2024M9    A       IT    L_2020  2025-03-04T04:49:48.949Z         ISTAT
# 4  2024M9    A       IT    L_2020  2025-03-04T04:49:48.949Z         ISTAT
#
#                    series_code  \
# 0  A.IT.B1GQ_1.L_2020.N.2024M9
# 1  A.IT.B1GQ_1.L_2020.N.2024M9
# 2  A.IT.B1GQ_1.L_2020.N.2024M9
# 3  A.IT.B1GQ_1.L_2020.N.2024M9
# 4  A.IT.B1GQ_1.L_2020.N.2024M9
#
#                                          series_name series_num
# 0  annual – Italy – OUTPUT APPROACH – chain linke...     Master
# 1  annual – Italy – OUTPUT APPROACH – chain linke...     Master
# 2  annual – Italy – OUTPUT APPROACH – chain linke...     Master
# 3  annual – Italy – OUTPUT APPROACH – chain linke...     Master
# 4  annual – Italy – OUTPUT APPROACH – chain linke...     Master

# %% [markdown]
# <font size=5, font color='blue'> python_df is the dataframe downloaded through Python API.

# %%
python_df = pd.read_pickle("ITA_3.pickle")
python_df.head()
# Out:
#   @frequency provider_code           dataset_code  \
# 0     annual         ISTAT  92_506_DF_DCCN_PILN_1
# 1     annual         ISTAT  92_506_DF_DCCN_PILN_1
# 2     annual         ISTAT  92_506_DF_DCCN_PILN_1
# 3     annual         ISTAT  92_506_DF_DCCN_PILN_1
# 4     annual         ISTAT  92_506_DF_DCCN_PILN_1
#
#                                  dataset_name                  series_code  \
# 0  Gross Domestic Product and main components  A.IT.B1GQ_1.L_2020.N.2024M9
# 1  Gross Domestic Product and main components  A.IT.B1GQ_1.L_2020.N.2024M9
# 2  Gross Domestic Product and main components  A.IT.B1GQ_1.L_2020.N.2024M9
# 3  Gross Domestic Product and main components  A.IT.B1GQ_1.L_2020.N.2024M9
# 4  Gross Domestic Product and main components  A.IT.B1GQ_1.L_2020.N.2024M9
#
#                                          series_name original_period  \
# 0  annual – Italy – OUTPUT APPROACH – chain linke...            1995
# 1  annual – Italy – OUTPUT APPROACH – chain linke...            1996
# 2  annual – Italy – OUTPUT APPROACH – chain linke...            1997
# 3  annual – Italy – OUTPUT APPROACH – chain linke...            1998
# 4  annual – Italy – OUTPUT APPROACH – chain linke...            1999
#
#       period original_value value  ... DATA_TYPE_AGGR VALUATION ADJUSTMENT  \
# 0 1995-01-01             NA  None  ...         B1GQ_1    L_2020          N
# 1 1996-01-01             NA  None  ...         B1GQ_1    L_2020          N
# 2 1997-01-01             NA  None  ...         B1GQ_1    L_2020          N
# 3 1998-01-01             NA  None  ...         B1GQ_1    L_2020          N
# 4 1999-01-01             NA  None  ...         B1GQ_1    L_2020          N
#
#   EDITION Frequency Territory        Aggregate  \
# 0  2024M9    annual     Italy  OUTPUT APPROACH
# 1  2024M9    annual     Italy  OUTPUT APPROACH
# 2  2024M9    annual     Italy  OUTPUT APPROACH
# 3  2024M9    annual     Italy  OUTPUT APPROACH
# 4  2024M9    annual     Italy  OUTPUT APPROACH
#
#                             Valuation Adjustment   Edition
# 0  chain linked - reference year 2020   raw data  Sep-2024
# 1  chain linked - reference year 2020   raw data  Sep-2024
# 2  chain linked - reference year 2020   raw data  Sep-2024
# 3  chain linked - reference year 2020   raw data  Sep-2024
# 4  chain linked - reference year 2020   raw data  Sep-2024
#
# [5 rows x 22 columns]

# %% [markdown]
# <font size=5, font color='blue'> Check whether the two dataframes have the same number of rows, which means equal number of data points / observations. Column numbers of the two dataframes may differ due to the difference between Stata and Python APIs, and so do the order, datatypes and names of columns and the order of rows, which is why we don't require a complete match between python_df and stata_df.

# %%
stata_df.shape[0]==python_df.shape[0]
# Out:
# True

# %% [markdown]
# <font size=5, font color='blue'> ['period_start_day'] in stata_df is the most accurate timestamp assigned to each observation (row). In python_df its equivalent is ['period'], so we rename it to match the column name in stata_df. We match the datatype of the two columns by converting both of them to pandas datetime objects. We also convert the datatype of ['value'] in stata_df and python_df to numeric.

# %%
python_df.rename(columns={'period':'period_start_day'},inplace=True)
stata_df['period_start_day'] = pd.to_datetime(stata_df['period_start_day'])
python_df['period_start_day'] = pd.to_datetime(python_df['period_start_day'])
stata_df['value'] = pd.to_numeric(stata_df['value'],'coerce')
python_df['value'] = pd.to_numeric(python_df['value'],'coerce')

# %% [markdown]
# <font size=5, font color='blue'> Check whether ['period_start_day', 'series_code'] can identify a unique row in both stata_df and python_df, if not then there is a duplication or error in Dbnomics.

# %%
cols = ['period_start_day', 'series_code']
sum(stata_df.duplicated(subset=cols))+sum(python_df.duplicated(subset=cols)) == 0
# Out:
# True

# %% [markdown]
# <font size=5, font color='blue'> Then we sort the two dataframes by ['period_start_day', 'series_code']. This ensures observations in the two dataframes are in the same order. Finally we check whether the two sub-frames [['period_start_day','series_code','value']] sliced from stata_df and python_df are exactly the same.

# %%
stata_sub = stata_df.sort_values(by=cols)[cols+['value']].reset_index(drop=True)
python_sub = python_df.sort_values(by=cols)[cols+['value']].reset_index(drop=True)
stata_sub.equals(python_sub)
# Out:
# True
