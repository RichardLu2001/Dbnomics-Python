# %%
import pandas as pd

from dbnomics import fetch_series, fetch_series_by_api_link

# %%
df = fetch_series("INE-SPAIN", "30680", dimensions={'units': ['euros']}, max_nb_series=1000000)
df.head()
# Out:
#   @frequency provider_code dataset_code                        dataset_name  \
# 0  quarterly     INE-SPAIN        30680  1.3 GDP mp Demand (Current prices)
# 1  quarterly     INE-SPAIN        30680  1.3 GDP mp Demand (Current prices)
# 2  quarterly     INE-SPAIN        30680  1.3 GDP mp Demand (Current prices)
# 3  quarterly     INE-SPAIN        30680  1.3 GDP mp Demand (Current prices)
# 4  quarterly     INE-SPAIN        30680  1.3 GDP mp Demand (Current prices)
#
#   series_code                                        series_name  \
# 0    CNTR4757  National Total. Seasonally and calendar adjust...
# 1    CNTR4757  National Total. Seasonally and calendar adjust...
# 2    CNTR4757  National Total. Seasonally and calendar adjust...
# 3    CNTR4757  National Total. Seasonally and calendar adjust...
# 4    CNTR4757  National Total. Seasonally and calendar adjust...
#
#   original_period     period  original_value     value  ... nac  units  \
# ...

# %%
df.to_csv('ESP_1.csv')

# %%
df.to_pickle('ESP_1.pickle')

# %%
df1 = pd.read_pickle('ESP_1.pickle')
df1.equals(df)
# Out:
# True
