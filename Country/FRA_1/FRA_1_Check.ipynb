# %% [markdown]
# <font size=5, font color='blue'> stata_df is the dataframe downloaded through Stata API

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

stata_df = pd.read_stata("FRA_1.dta")
stata_df.head()
# Out:
#     period period_start_day    value OBS_CONF OBS_STATUS _frequency  \
# 0  1970-01       1970-01-01  58833.0        F          A    monthly
# 1  1970-02       1970-02-01  58303.0        F          A    monthly
# 2  1970-03       1970-03-01  58854.0        F          A    monthly
# 3  1970-04       1970-04-01  59195.0        F          A    monthly
# 4  1970-05       1970-05-01  58925.0        F          A    monthly
#
#   dataset_code                            dataset_name ADJUSTMENT  \
# 0         BSI1  Data on monetary aggregates in France.          N
# 1         BSI1  Data on monetary aggregates in France.          N
# 2         BSI1  Data on monetary aggregates in France.          N
# 3         BSI1  Data on monetary aggregates in France.          N
# 4         BSI1  Data on monetary aggregates in France.          N
#
#   BS_COUNT_SECTOR  ... COUNT_AREA CURRENCY_TRANS DATA_TYPE FREQ MATURITY_ORIG  \
# 0            2300  ...         U2            Z01         1    M             A
# 1            2300  ...         U2            Z01         1    M             A
# 2            2300  ...         U2            Z01         1    M             A
# 3            2300  ...         U2            Z01         1    M             A
# 4            2300  ...         U2            Z01         1    M             A
#
#   REF_AREA                indexed_at provider_code  \
# 0       FR  2025-06-13T07:20:01.059Z           BDF
# 1       FR  2025-06-13T07:20:01.059Z           BDF
# 2       FR  2025-06-13T07:20:01.059Z           BDF
# 3       FR  2025-06-13T07:20:01.059Z           BDF
# 4       FR  2025-06-13T07:20:01.059Z           BDF
#
#                       series_code                             series_name
# 0  M.FR.N.V.M30.A.1.U2.2300.Z01.E  France monetary agregates, M3 [stocks]
# 1  M.FR.N.V.M30.A.1.U2.2300.Z01.E  France monetary agregates, M3 [stocks]
# 2  M.FR.N.V.M30.A.1.U2.2300.Z01.E  France monetary agregates, M3 [stocks]
# 3  M.FR.N.V.M30.A.1.U2.2300.Z01.E  France monetary agregates, M3 [stocks]
# 4  M.FR.N.V.M30.A.1.U2.2300.Z01.E  France monetary agregates, M3 [stocks]
#
# [5 rows x 23 columns]

# %% [markdown]
# <font size=5, font color='blue'> python_df is the dataframe downloaded through Python API.

# %%
python_df = pd.read_pickle("FRA_1.pkl")
python_df.head()
# Out:
#   @frequency provider_code dataset_code  \
# 0    monthly           BDF         BSI1
# 1    monthly           BDF         BSI1
# 2    monthly           BDF         BSI1
# 3    monthly           BDF         BSI1
# 4    monthly           BDF         BSI1
#
#                              dataset_name                     series_code  \
# 0  Data on monetary aggregates in France.  M.FR.N.V.M10.A.1.U2.2300.Z01.E
# 1  Data on monetary aggregates in France.  M.FR.N.V.M10.A.1.U2.2300.Z01.E
# 2  Data on monetary aggregates in France.  M.FR.N.V.M10.A.1.U2.2300.Z01.E
# 3  Data on monetary aggregates in France.  M.FR.N.V.M10.A.1.U2.2300.Z01.E
# 4  Data on monetary aggregates in France.  M.FR.N.V.M10.A.1.U2.2300.Z01.E
#
#                               series_name original_period     period  \
# 0  France monetary agregates, M1 [stocks]         1970-01 1970-01-01
# 1  France monetary agregates, M1 [stocks]         1970-02 1970-02-01
# 2  France monetary agregates, M1 [stocks]         1970-03 1970-03-01
# 3  France monetary agregates, M1 [stocks]         1970-04 1970-04-01
# 4  France monetary agregates, M1 [stocks]         1970-05 1970-05-01
#
#   original_value  value  ... Area code list  \
# 0             NA    NaN  ...         France
# 1             NA    NaN  ...         France
# 2             NA    NaN  ...         France
# 3             NA    NaN  ...         France
# 4             NA    NaN  ...         France
#
#                 Adjustment indicator code list  \
# 0  Neither seasonally nor working day adjusted
# 1  Neither seasonally nor working day adjusted
# 2  Neither seasonally nor working day adjusted
# 3  Neither seasonally nor working day adjusted
# 4  Neither seasonally nor working day adjusted
#
#             Balance sheet reference sector breakdown     Balance sheet item  \
# 0  MFIs, central government and post office giro ...  Monetary aggregate M1
# 1  MFIs, central government and post office giro ...  Monetary aggregate M1
# 2  MFIs, central government and post office giro ...  Monetary aggregate M1
# 3  MFIs, central government and post office giro ...  Monetary aggregate M1
# 4  MFIs, central government and post office giro ...  Monetary aggregate M1
#
#   Original maturity                                          Data Type  \
# 0             Total  Outstanding amounts at the end of the period (...
# 1             Total  Outstanding amounts at the end of the period (...
# 2             Total  Outstanding amounts at the end of the period (...
# 3             Total  Outstanding amounts at the end of the period (...
# 4             Total  Outstanding amounts at the end of the period (...
#
#                Counterpart geo area       Balance sheet counterpart sector  \
# 0  Euro area (changing composition)  Non-MFIs excluding central government
# 1  Euro area (changing composition)  Non-MFIs excluding central government
# 2  Euro area (changing composition)  Non-MFIs excluding central government
# 3  Euro area (changing composition)  Non-MFIs excluding central government
# 4  Euro area (changing composition)  Non-MFIs excluding central government
#
#         Currency code list Suffix
# 0  All currencies combined   Euro
# 1  All currencies combined   Euro
# 2  All currencies combined   Euro
# 3  All currencies combined   Euro
# 4  All currencies combined   Euro
#
# [5 rows x 32 columns]

# %% [markdown]
# <font size=5, font color='blue'> Check whether the two dataframes have the same number of rows, which means equal number of data points / observations. Column numbers of the two dataframes may differ due to the difference between Stata and Python APIs, and so do the order, datatypes and names of columns and the order of rows, which is why we don't require a complete match between python_df and stata_df.

# %%
stata_df.shape[0]==python_df.shape[0]
# Out:
# True

# %% [markdown]
# <font size=5, font color='blue'> ['period_start_day'] in stata_df is the most accurate timestamp assigned to each observation (row). In python_df its equivalent is ['period'], so we rename it to match the column name in stata_df. We match the datatype of the two columns by converting both of them to pandas datetime objects. We also convert the datatype of ['value'] in stata_df to numeric.

# %%
python_df.rename(columns={'period':'period_start_day'},inplace=True)
stata_df['period_start_day'] = pd.to_datetime(stata_df['period_start_day'])
python_df['period_start_day'] = pd.to_datetime(python_df['period_start_day'])
stata_df['value'] = pd.to_numeric(stata_df['value'],'coerce').astype('float64')

# %% [markdown]
# <font size=5, font color='blue'> Check whether ['period_start_day', 'series_code'] can identify a unique row in both stata_df and python_df, if not then there is a duplication or error in Dbnomics.

# %%
cols = ['period_start_day', 'series_code']
sum(stata_df.duplicated(subset=cols))+sum(python_df.duplicated(subset=cols)) == 0
# Out:
# True

# %% [markdown]
# <font size=5, font color='blue'> Then we sort the two dataframes by ['period_start_day', 'series_code']. This ensures observations in the two dataframes are in the same order. Finally we check whether the two sub-frames [['period_start_day','series_code','value']] sliced from stata_df and python_df are exactly the same.

# %%
stata_sub = stata_df.sort_values(by=cols)[cols+['value']].reset_index(drop=True)
python_sub = python_df.sort_values(by=cols)[cols+['value']].reset_index(drop=True)
stata_sub.equals(python_sub)
# Out:
# True
