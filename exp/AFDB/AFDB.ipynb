# %%
import pandas as pd

from dbnomics import fetch_series

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
indicators = ["NY.GDP.MKTP.CN",'FM.LBL.MONY.CN','FM.LBL.MQMY.CN','GC.REV.TAX.GD.CN','GC.REV.TOTL.GD.ZS','GC.REV.TOTL.GD.CN','GC.XPN.TOTL.GD.ZS','GC.XPN.TOTL.GD.CN','GC.BAL.CASH.GD.ZS','GC.BAL.CASH.GD.CN','SL.TLF.15UP.UEM','LM.POP.EPP.TOT']

# %%
df = fetch_series("AFDB", "bbkawjf", dimensions={"indicator": indicators}, max_nb_series=1000000)
df = df.reset_index(drop=True)
df.head(20)
# Out:
#    @frequency provider_code dataset_code                  dataset_name  \
# 0      annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 1      annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 2      annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 3      annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 4      annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 5      annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 6      annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 7      annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 8      annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 9      annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 10     annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 11     annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 12     annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 13     annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 14     annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 15     annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 16     annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 17     annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 18     annual          AFDB      bbkawjf  AFDB Socio Economic Database
# 19     annual          AFDB      bbkawjf  AFDB Socio Economic Database
#
#            series_code                   series_name original_period  \
# 0   FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            1995
# 1   FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            1996
# 2   FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            1997
# 3   FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            1998
# 4   FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            1999
# 5   FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            2000
# 6   FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            2001
# 7   FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            2002
# 8   FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            2003
# 9   FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            2004
# 10  FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            2005
# 11  FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            2006
# 12  FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            2007
# 13  FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            2008
# 14  FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            2009
# 15  FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            2010
# 16  FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            2011
# 17  FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            2012
# 18  FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            2013
# 19  FM.LBL.MONY.CN.AGO  Money (current LCU) - Angola            2014
#
#        period        original_value         value country       indicator  \
# 0  1995-01-01             2689020.0  2.689020e+06     AGO  FM.LBL.MONY.CN
# 1  1996-01-01            93917900.0  9.391790e+07     AGO  FM.LBL.MONY.CN
# 2  1997-01-01           194910000.0  1.949100e+08     AGO  FM.LBL.MONY.CN
# 3  1998-01-01           272432000.0  2.724320e+08     AGO  FM.LBL.MONY.CN
# 4  1999-01-01          1206550000.0  1.206550e+09     AGO  FM.LBL.MONY.CN
# 5  2000-01-01    15840411639.280001  1.584041e+10     AGO  FM.LBL.MONY.CN
# 6  2001-01-01    41660774283.559898  4.166077e+10     AGO  FM.LBL.MONY.CN
# 7  2002-01-01   106793512283.316986  1.067935e+11     AGO  FM.LBL.MONY.CN
# 8  2003-01-01   179518093989.351013  1.795181e+11     AGO  FM.LBL.MONY.CN
# 9  2004-01-01   266677656751.022003  2.666777e+11     AGO  FM.LBL.MONY.CN
# 10 2005-01-01   428566980082.890015  4.285670e+11     AGO  FM.LBL.MONY.CN
# 11 2006-01-01   685068282991.180054  6.850683e+11     AGO  FM.LBL.MONY.CN
# 12 2007-01-01  1023638868705.589966  1.023639e+12     AGO  FM.LBL.MONY.CN
# 13 2008-01-01  2094018359082.639893  2.094018e+12     AGO  FM.LBL.MONY.CN
# 14 2009-01-01  2543723059447.950195  2.543723e+12     AGO  FM.LBL.MONY.CN
# 15 2010-01-01  2678230070993.430176  2.678230e+12     AGO  FM.LBL.MONY.CN
# 16 2011-01-01  3673111017825.330078  3.673111e+12     AGO  FM.LBL.MONY.CN
# 17 2012-01-01  3853026880550.060059  3.853027e+12     AGO  FM.LBL.MONY.CN
# 18 2013-01-01  4398099013490.820312  4.398099e+12     AGO  FM.LBL.MONY.CN
# 19 2014-01-01  5110115937912.120117  5.110116e+12     AGO  FM.LBL.MONY.CN
#
#           units scale frequency Country            Indicator        Units  \
# 0   current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 1   current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 2   current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 3   current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 4   current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 5   current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 6   current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 7   current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 8   current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 9   current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 10  current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 11  current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 12  current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 13  current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 14  current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 15  current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 16  current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 17  current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 18  current-lcu     1         A  Angola  Money (current LCU)  current LCU
# 19  current-lcu     1         A  Angola  Money (current LCU)  current LCU
#
#    Scale Frequency
# 0      1    Annual
# 1      1    Annual
# 2      1    Annual
# 3      1    Annual
# 4      1    Annual
# 5      1    Annual
# 6      1    Annual
# 7      1    Annual
# 8      1    Annual
# 9      1    Annual
# 10     1    Annual
# 11     1    Annual
# 12     1    Annual
# 13     1    Annual
# 14     1    Annual
# 15     1    Annual
# 16     1    Annual
# 17     1    Annual
# 18     1    Annual
# 19     1    Annual

# %%
df.to_excel('AFDB.xlsx')

# %%
df.to_pickle("AFDB.pkl")

# %%
df1 = pd.read_pickle("AFDB.pkl")
df1.equals(df)
# Out:
# True
